# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
training_data=[
  [
    "Ingredients: 2 cups of penne pasta, 1 cup of cherry tomatoes, 1/2 cup of fresh basil leaves, 3 cloves of garlic, 1/4 cup of olive oil, Salt and pepper to taste, Grated Parmesan cheese (optional)",
    "Instructions: Cook the penne pasta according to package instructions. While pasta is cooking, blend cherry tomatoes, basil, garlic, and olive oil until smooth. Season with salt and pepper. Toss the cooked pasta with the tomato-basil sauce. Serve with grated Parmesan cheese if desired."
  ],
  [
    "Ingredients: 500 grams of chicken thighs, 1/4 cup of soy sauce, 2 tablespoons of honey, 2 cloves of garlic (minced), 1 teaspoon of grated ginger, 1 tablespoon of vegetable oil, Sesame seeds (for garnish), Sliced green onions (for garnish)",
    "Instructions: In a bowl, mix soy sauce, honey, garlic, and ginger. Marinate chicken in this mixture for 30 minutes. Heat oil in a pan and cook chicken until browned and cooked through. Garnish with sesame seeds and sliced green onions."
  ],
  [
    "Ingredients: 2 large potatoes, 1/2 cup of mayonnaise, 2 tablespoons of mustard, 1/4 cup of diced pickles, 1/4 cup of diced onion, Salt and pepper to taste",
    "Instructions: Boil and dice the potatoes. Mix mayo, mustard, pickles, and onions in a bowl. Add diced potatoes and season with salt and pepper. Chill before serving for a classic potato salad."
  ],
  [
    "Ingredients: 2 cups of fresh spinach, 1 banana, 1/2 cup of frozen berries (e.g., strawberries, blueberries), 1 cup of almond milk, 1 tablespoon of honey (optional), 1/2 cup of Greek yogurt",
    "Instructions: Blend spinach, banana, berries, almond milk, honey (if desired), and Greek yogurt until smooth. Enjoy a nutritious green smoothie."
  ],
  [
    "Ingredients: 1 pound of ground beef, 1 onion (chopped), 1 green bell pepper (chopped), 1 can of diced tomatoes, 1 can of kidney beans, 1 can of black beans, 2 tablespoons of chili powder, Salt and pepper to taste",
    "Instructions: In a pot, cook beef until browned. Add onions and bell peppers, cook until softened. Add diced tomatoes, drained beans, chili powder, salt, and pepper. Simmer for 20-30 minutes."
  ],
  [
    "Ingredients: 2 cups of all-purpose flour, 1 tablespoon of sugar, 1 tablespoon of baking powder, 1/2 teaspoon of salt, 2 cups of milk, 2 eggs, 2 tablespoons of melted butter",
    "Instructions: In a bowl, mix flour, sugar, baking powder, and salt. In another bowl, whisk together milk, eggs, and melted butter. Combine wet and dry ingredients. Cook pancakes on a hot griddle."
  ],
  [
    "Ingredients: 2 cups of sushi rice, 1/2 cup of rice vinegar, 2 tablespoons of sugar, 1 teaspoon of salt, Nori seaweed sheets, Sushi fillings (e.g., fish, avocado, cucumber), Soy sauce and wasabi (for serving)",
    "Instructions: Cook sushi rice and season with a mixture of rice vinegar, sugar, and salt. Lay a sheet of nori on a bamboo sushi rolling mat, add rice, and fillings. Roll tightly, slice, and serve with soy sauce and wasabi."
  ],
  [
    "Ingredients: 1 pound of spaghetti, 3 cloves of garlic (minced), 1/4 cup of olive oil, Red pepper flakes (to taste), Fresh parsley (chopped), Grated Pecorino Romano cheese",
    "Instructions: Cook spaghetti according to package directions. In a pan, sauté garlic and red pepper flakes in olive oil. Toss cooked pasta in the garlic oil mixture. Garnish with parsley and cheese."
  ],
  [
    "Ingredients: 2 ripe avocados, 1 small onion (chopped), 1 clove of garlic (minced), 1 tomato (diced), 1 lime (juiced), Salt and pepper to taste, Fresh cilantro (chopped, optional)",
    "Instructions: Mash avocados in a bowl. Stir in onion, garlic, tomato, lime juice, salt, and pepper. Garnish with cilantro if desired. Serve guacamole with tortilla chips."
  ],
  [
    "Ingredients: 2 cups of cooked quinoa, 1 cup of black beans, 1 cup of corn kernels, 1 red bell pepper (diced), 1 cup of diced zucchini, 2 tablespoons of olive oil, 1 teaspoon of cumin, Salt and pepper to taste",
    "Instructions: Combine quinoa, black beans, corn, red bell pepper, and zucchini in a bowl. In a separate bowl, whisk together olive oil, cumin, salt, and pepper. Pour dressing over the quinoa salad and toss to combine."
  ],
  [
    "Ingredients: 1 pound of ground pork, 1/4 cup of breadcrumbs, 1/4 cup of milk, 1/4 cup of grated Parmesan cheese, 1/4 cup of chopped parsley, 1 egg, 2 cloves of garlic (minced), Salt and pepper to taste, Marinara sauce, Cooked spaghetti",
    "Instructions: In a bowl, combine ground pork, breadcrumbs, milk, Parmesan cheese, parsley, egg, garlic, salt, and pepper. Form into meatballs and cook in marinara sauce. Serve over cooked spaghetti."
  ],
  [
    "Ingredients: 2 cups of watermelon chunks, 1 cup of cucumber slices, 1/4 cup of fresh mint leaves, 1 lime (juiced), 1 tablespoon of honey (optional), Ice cubes",
    "Instructions: Blend watermelon, cucumber, mint leaves, lime juice, and honey (if desired) until smooth. Serve over ice for a refreshing summer drink."
  ],
  [
    "Ingredients: 2 cups of cooked and shredded chicken, 1/2 cup of buffalo sauce, 2 tablespoons of butter, 1/2 cup of ranch dressing, 1 cup of shredded cheddar cheese, 1/4 cup of sliced green onions, Tortilla chips or celery sticks (for dipping)",
    "Instructions: In a saucepan, combine shredded chicken, buffalo sauce, and butter. Cook until heated through. In a serving dish, layer ranch dressing, the buffalo chicken mixture, cheddar cheese, and green onions. Serve with tortilla chips or celery sticks."
  ],
  [
    "Ingredients: 2 cups of old-fashioned rolled oats, 1/2 cup of almond butter, 1/3 cup of honey, 1/4 cup of mini chocolate chips, 1/4 cup of dried cranberries, 1/4 cup of chopped nuts (e.g., almonds or walnuts), 1 teaspoon of vanilla extract, Pinch of salt",
    "Instructions: In a large bowl, mix oats, almond butter, honey, chocolate chips, dried cranberries, nuts, vanilla extract, and a pinch of salt. Press into a lined pan and refrigerate until firm. Cut into bars and enjoy as homemade granola bars."
  ],
  [
    "Ingredients: 2 cups of cooked and shredded beef (e.g., brisket or chuck roast), 1 cup of BBQ sauce, 4 hamburger buns, Coleslaw (optional, for topping)",
    "Instructions: Mix shredded beef and BBQ sauce in a pan and cook until heated through. Serve on hamburger buns with coleslaw if desired for a delicious BBQ beef sandwich."
  ],
  [
    "Ingredients: 2 cups of quinoa, 4 cups of vegetable broth, 1 cup of diced carrots, 1 cup of frozen peas, 1 cup of diced bell peppers, 1 cup of diced zucchini, 2 tablespoons of olive oil, 1 teaspoon of curry powder, Salt and pepper to taste",
    "Instructions: In a large pot, heat olive oil and sauté carrots, bell peppers, and zucchini until slightly softened. Add quinoa and curry powder, stirring for a minute. Pour in vegetable broth and bring to a boil. Reduce heat, cover, and simmer for 15-20 minutes. Stir in frozen peas, cook for a few more minutes, and season with salt and pepper. Serve as a hearty vegetable quinoa bowl."
  ],
  [
    "Ingredients: 2 ripe mangoes (peeled and cubed), 1/2 cup of plain yogurt, 1/2 cup of orange juice, 1 tablespoon of honey (optional), Ice cubes",
    "Instructions: Blend mango cubes, yogurt, orange juice, and honey (if desired) until smooth. Add ice cubes and blend again for a refreshing mango smoothie."
  ],
  [
    "Ingredients: 1 pound of shrimp (peeled and deveined), 1/4 cup of olive oil, 2 cloves of garlic (minced), 1 teaspoon of smoked paprika, 1/2 teaspoon of cayenne pepper, Salt and pepper to taste, Lemon wedges (for serving)",
    "Instructions: In a bowl, mix olive oil, minced garlic, smoked paprika, cayenne pepper, salt, and pepper. Add shrimp and toss to coat. Thread shrimp onto skewers and grill until cooked through. Serve with lemon wedges for a flavorful shrimp skewer."
  ],
  [
    "Ingredients: 2 cups of all-purpose flour, 1 teaspoon of baking powder, 1/2 teaspoon of salt, 1/4 cup of sugar, 1/4 cup of unsalted butter (cold and cubed), 2/3 cup of milk, 1 teaspoon of vanilla extract, Fruit preserves or jam (for filling), Powdered sugar (for dusting)",
    "Instructions: In a bowl, mix flour, baking powder, salt, and sugar. Cut in cold butter until the mixture resembles coarse crumbs. Stir in milk and vanilla extract to form a dough. Roll out dough and cut into rounds. Place a teaspoon of fruit preserves or jam in the center of each round. Fold in half, sealing edges. Bake until golden, then dust with powdered sugar for delicious jam-filled pastries."
  ],
  [
    "Ingredients: 1 cup of old-fashioned oats, 1/2 cup of peanut butter, 1/3 cup of honey, 1/2 cup of ground flaxseed, 1/2 cup of mini chocolate chips, 1 teaspoon of vanilla extract",
    "Instructions: Mix oats, peanut butter, honey, flaxseed, chocolate chips, and vanilla extract in a bowl. Roll into small balls and refrigerate until firm. These no-bake energy bites are a healthy snack for kids and moms-to-be."
  ],
  [
    "Ingredients: 2 cups of whole wheat flour, 1 cup of mashed ripe bananas, 1/2 cup of plain yogurt, 1/4 cup of honey, 2 eggs, 1 teaspoon of baking powder, 1/2 teaspoon of cinnamon",
    "Instructions: Preheat oven to 350°F (175°C). Mix flour, mashed bananas, yogurt, honey, eggs, baking powder, and cinnamon. Pour into a greased loaf pan and bake for about 45-50 minutes. This banana bread is a nutritious treat."
  ],
  [
    "Ingredients: 1 cup of cooked quinoa, 1/2 cup of grated carrot, 1/2 cup of grated zucchini, 1/4 cup of grated cheddar cheese, 1/4 cup of breadcrumbs, 1 egg, 1/2 teaspoon of garlic powder, Salt and pepper to taste",
    "Instructions: Combine quinoa, grated carrot, zucchini, cheddar cheese, breadcrumbs, egg, garlic powder, salt, and pepper in a bowl. Form into patties and cook in a skillet until golden. Serve as quinoa veggie burgers."
  ],
  [
    "Ingredients: 2 cups of mixed berries (e.g., strawberries, blueberries, raspberries), 1/2 cup of Greek yogurt, 1/4 cup of honey, 1/4 cup of almond milk, 1 teaspoon of vanilla extract",
    "Instructions: Blend mixed berries, Greek yogurt, honey, almond milk, and vanilla extract until smooth. Pour into popsicle molds and freeze for a refreshing and healthy snack for kids and moms-to-be."
  ],
  [
    "Ingredients: 1 cup of cottage cheese, 1 ripe avocado, 1 tablespoon of lime juice, 1/2 teaspoon of garlic powder, Salt and pepper to taste, Whole-grain crackers or baby carrots (for dipping)",
    "Instructions: Blend cottage cheese, ripe avocado, lime juice, garlic powder, salt, and pepper until creamy. Serve as a nutritious avocado-cottage cheese dip with whole-grain crackers or baby carrots."
  ],
  [
    "Ingredients: 2 cups of cooked and shredded chicken breast, 1/2 cup of plain Greek yogurt, 1/4 cup of diced celery, 1/4 cup of chopped apples, 1/4 cup of dried cranberries, 1/4 cup of chopped walnuts, Salt and pepper to taste, Whole wheat bread or lettuce leaves (for making sandwiches)",
    "Instructions: Mix shredded chicken breast, Greek yogurt, celery, apples, dried cranberries, walnuts, salt, and pepper in a bowl. Serve as a chicken salad in sandwiches or lettuce wraps for a protein-packed meal."
  ],
  [
    "Ingredients: 1 cup of cooked and mashed sweet potatoes, 1/2 cup of oat flour, 1/4 cup of almond butter, 1/4 cup of maple syrup, 1/4 cup of unsweetened applesauce, 1/2 teaspoon of cinnamon, 1/2 teaspoon of baking powder",
    "Instructions: Preheat oven to 350°F (175°C). Mix mashed sweet potatoes, oat flour, almond butter, maple syrup, applesauce, cinnamon, and baking powder. Drop spoonfuls onto a baking sheet and bake for about 12-15 minutes. These sweet potato cookies are a kid-friendly and pregnancy-safe treat."
  ],
  [
    "Ingredients: 2 cups of whole wheat pasta, 1 cup of broccoli florets, 1/2 cup of diced bell peppers, 1/4 cup of grated Parmesan cheese, 2 tablespoons of olive oil, 1 teaspoon of Italian seasoning, Salt and pepper to taste",
    "Instructions: Cook whole wheat pasta according to package directions. Steam broccoli until tender. Toss pasta, broccoli, bell peppers, Parmesan cheese, olive oil, Italian seasoning, salt, and pepper in a bowl. A simple and nutritious pasta salad for everyone."
  ],
  [
    "Ingredients: 1 cup of rolled oats, 1/2 cup of almond butter, 1/4 cup of honey, 1/4 cup of unsweetened coconut flakes, 1/4 cup of dried apricots (chopped), 1/4 cup of dark chocolate chips",
    "Instructions: Mix rolled oats, almond butter, honey, coconut flakes, chopped dried apricots, and dark chocolate chips in a bowl. Roll into bite-sized balls and refrigerate. These energy bites are perfect for kids and expectant mothers."
  ],
  [
    "Ingredients: 2 cups of cooked and shredded rotisserie chicken, 1/2 cup of Greek yogurt, 1/4 cup of diced celery, 1/4 cup of grapes (halved), 1/4 cup of chopped walnuts, Salt and pepper to taste, Whole grain bread or lettuce leaves (for making wraps)",
    "Instructions: Combine shredded rotisserie chicken, Greek yogurt, celery, grapes, chopped walnuts, salt, and pepper in a bowl. Serve as chicken salad wraps in whole grain bread or lettuce leaves for a satisfying and nutritious meal."
  ],
  [
    "Ingredients: 1 cup of cooked quinoa, 1/2 cup of diced cucumber, 1/2 cup of diced red bell pepper, 1/4 cup of crumbled feta cheese, 2 tablespoons of olive oil, 2 tablespoons of lemon juice, 1 teaspoon of dried oregano, Salt and pepper to taste",
    "Instructions: Mix cooked quinoa, diced cucumber, diced red bell pepper, crumbled feta cheese, olive oil, lemon juice, dried oregano, salt, and pepper in a bowl. A quinoa Greek salad that's light and refreshing for all ages."
  ],
  [
    "Ingredients: 1 cup of cooked and mashed butternut squash, 1/2 cup of almond flour, 1/4 cup of grated Parmesan cheese, 1/4 cup of chopped fresh sage leaves, Salt and pepper to taste",
    "Instructions: Preheat oven to 350°F (175°C). Combine mashed butternut squash, almond flour, grated Parmesan cheese, chopped fresh sage leaves, salt, and pepper. Form into small patties and bake for about 20-25 minutes. These butternut squash and sage fritters are a tasty and nutritious option."
  ],
  [
    "Ingredients: 2 cups of mixed berries (e.g., blueberries, strawberries), 1/2 cup of plain yogurt, 1/4 cup of honey, 1/4 cup of milk, 1/2 teaspoon of vanilla extract",
    "Instructions: Blend mixed berries, plain yogurt, honey, milk, and vanilla extract until smooth. Pour into ice pop molds and freeze for a delightful and wholesome treat for kids and moms-to-be."
  ],
  [
    "Ingredients: 1 cup of cooked and mashed sweet potatoes, 1/2 cup of cooked and pureed spinach, 1/4 cup of grated cheddar cheese, 1/4 cup of whole wheat breadcrumbs, 1 egg, 1/2 teaspoon of garlic powder, Salt and pepper to taste",
    "Instructions: Mix mashed sweet potatoes, pureed spinach, grated cheddar cheese, whole wheat breadcrumbs, egg, garlic powder, salt, and pepper in a bowl. Form into small patties and cook in a skillet until golden. These sweet potato and spinach cakes are a nutritious choice."
  ],
  [
    "Ingredients: 2 cups of cooked and shredded rotisserie chicken, 1/2 cup of diced apples, 1/2 cup of diced celery, 1/4 cup of dried cranberries, 1/4 cup of plain Greek yogurt, 1/4 cup of mayonnaise, 1 teaspoon of curry powder, Salt and pepper to taste, Whole grain bread or lettuce leaves (for making wraps)",
    "Instructions: Combine shredded rotisserie chicken, diced apples, diced celery, dried cranberries, plain Greek yogurt, mayonnaise, curry powder, salt, and pepper in a bowl. Serve as chicken salad wraps in whole grain bread or lettuce leaves for a delightful meal."
  ],
  [
    "Ingredients: 2 cups of cooked and mashed pumpkin, 1 cup of rolled oats, 1/4 cup of almond butter, 1/4 cup of maple syrup, 1/4 cup of unsweetened applesauce, 1 teaspoon of pumpkin pie spice, 1/2 teaspoon of vanilla extract",
    "Instructions: Preheat oven to 350°F (175°C). Mix mashed pumpkin, rolled oats, almond butter, maple syrup, applesauce, pumpkin pie spice, and vanilla extract. Drop spoonfuls onto a baking sheet and bake for about 12-15 minutes. These pumpkin oatmeal cookies are a kid-friendly and pregnancy-safe treat."
  ],
  [
    "Ingredients: 2 cups of cooked and shredded chicken breast, 1/2 cup of diced mango, 1/2 cup of diced red bell pepper, 1/4 cup of chopped fresh cilantro, 1/4 cup of plain Greek yogurt, 1/4 cup of mayonnaise, 1 tablespoon of lime juice, Salt and pepper to taste, Whole wheat bread or lettuce leaves (for making wraps)",
    "Instructions: Combine shredded chicken breast, diced mango, diced red bell pepper, chopped fresh cilantro, plain Greek yogurt, mayonnaise, lime juice, salt, and pepper in a bowl. Serve as chicken and mango wraps in whole wheat bread or lettuce leaves for a tropical and satisfying meal."
  ],
  [
    "Ingredients: 2 large russet potatoes, Vegetable oil for frying, Salt to taste",
    "Instructions: Peel and cut potatoes into thin strips. Heat vegetable oil in a deep fryer or skillet. Fry the potatoes until golden brown and crispy. Drain on paper towels, season with salt, and enjoy homemade french fries."
  ],
  [
    "Ingredients: 1 pound of ground beef, 4 burger buns, 4 slices of American cheese, Ketchup, Mustard, Pickles, Sliced onions, Lettuce, Tomato slices",
    "Instructions: Form ground beef into 4 patties and grill or pan-fry to your desired doneness. Place American cheese slices on the hot patties to melt. Assemble burgers with ketchup, mustard, pickles, sliced onions, lettuce, and tomato slices in buns for classic cheeseburgers."
  ],
  [
    "Ingredients: 2 cups of elbow macaroni, 2 cups of shredded cheddar cheese, 1/2 cup of milk, 2 tablespoons of butter, 2 tablespoons of all-purpose flour, Salt and pepper to taste",
    "Instructions: Cook macaroni according to package instructions. In a saucepan, melt butter, stir in flour, then gradually add milk while stirring. Add cheddar cheese and stir until melted. Combine cheese sauce with cooked macaroni, season with salt and pepper, and serve creamy mac and cheese."
  ],
  [
    "Ingredients: 4 hot dog sausages, 4 hot dog buns, Ketchup, Mustard, Relish, Chopped onions, Sauerkraut (optional)",
    "Instructions: Grill or pan-fry hot dog sausages until heated through and slightly charred. Place in hot dog buns and add condiments like ketchup, mustard, relish, chopped onions, and sauerkraut for classic hot dogs."
  ],
  [
    "Ingredients: 1 pound of ground beef, 1 packet of taco seasoning, 8 taco shells, Shredded lettuce, Diced tomatoes, Shredded cheddar cheese, Sour cream, Salsa",
    "Instructions: Brown ground beef, drain excess fat, and add taco seasoning with water per packet instructions. Fill taco shells with seasoned beef, lettuce, diced tomatoes, cheddar cheese, sour cream, and salsa for tasty beef tacos."
  ],
  [
    "Ingredients: 2 boneless, skinless chicken breasts, 1 cup of buttermilk, 1 cup of all-purpose flour, 1 teaspoon of paprika, 1 teaspoon of garlic powder, Salt and pepper to taste, Vegetable oil for frying, Hamburger buns, Mayonnaise, Pickles, Lettuce",
    "Instructions: Marinate chicken breasts in buttermilk. In a bowl, combine flour, paprika, garlic powder, salt, and pepper. Remove chicken from buttermilk, coat in flour mixture, and fry in hot oil until golden and cooked through. Assemble sandwiches with buns, mayonnaise, pickles, and lettuce for crispy chicken sandwiches."
  ],
  [
    "Ingredients: Pizza dough, Tomato sauce, Shredded mozzarella cheese, Toppings of your choice (e.g., pepperoni, bell peppers, mushrooms)",
    "Instructions: Roll out pizza dough, spread tomato sauce, add shredded mozzarella cheese, and your favorite toppings. Bake in a preheated oven according to dough instructions until cheese is bubbly and crust is golden. Slice and enjoy homemade pizza."
  ],
  [
    "Ingredients: 2 cups of cooked spaghetti, 1/2 cup of marinara sauce, 1/4 cup of grated Parmesan cheese, 1/4 cup of bread crumbs, 1 egg, 1 cup of mozzarella cheese (shredded)",
    "Instructions: Preheat oven to 375°F (190°C). Mix cooked spaghetti with marinara sauce and half of the Parmesan cheese. In a greased baking dish, spread spaghetti mixture. In a bowl, combine bread crumbs, remaining Parmesan cheese, and egg. Sprinkle over the spaghetti. Top with shredded mozzarella cheese. Bake until cheese is melted and bubbly, and the top is golden brown. Serve as spaghetti pie."
  ],
  [
    "Ingredients: 2 large russet potatoes, Vegetable oil for frying, Salt, 1/4 cup of grated Parmesan cheese, 1 teaspoon of garlic powder, 1 teaspoon of dried parsley flakes",
    "Instructions: Cut potatoes into thin strips. Heat vegetable oil in a deep fryer or skillet. Fry the potatoes until golden brown and crispy. Drain on paper towels, season with salt, Parmesan cheese, garlic powder, and dried parsley flakes for delicious garlic Parmesan fries."
  ],
  [
    "Ingredients: 1 pound of ground beef, 1 packet of sloppy joe seasoning mix, 1 cup of ketchup, 1/2 cup of water, 4 hamburger buns",
    "Instructions: Brown ground beef, drain excess fat, and add sloppy joe seasoning mix, ketchup, and water. Simmer until thickened. Serve on hamburger buns for classic sloppy joes."
  ],
  [
    "Ingredients: 4 boneless, skinless chicken breasts, 1 cup of buttermilk, 1 cup of all-purpose flour, 1 teaspoon of paprika, 1 teaspoon of garlic powder, Salt and pepper to taste, Vegetable oil for frying, Hamburger buns, Mayonnaise, Lettuce, Tomato slices",
    "Instructions: Marinate chicken breasts in buttermilk. In a bowl, combine flour, paprika, garlic powder, salt, and pepper. Remove chicken from buttermilk, coat in flour mixture, and fry in hot oil until golden and cooked through. Assemble sandwiches with buns, mayonnaise, lettuce, and tomato slices for crispy chicken sandwiches."
  ],
  [
    "Ingredients: 4 hot dog sausages, 4 slices of bacon, 4 hot dog buns, Ketchup, Mustard, Onions, Shredded cheddar cheese",
    "Instructions: Wrap hot dog sausages with bacon slices and grill or pan-fry until bacon is crispy and sausages are heated through. Place in hot dog buns and add condiments like ketchup, mustard, onions, and shredded cheddar cheese for bacon-wrapped hot dogs."
  ],
  [
    "Ingredients: 1 pound of ground beef, 1 packet of chili seasoning mix, 1 can of chili beans, 1 can of diced tomatoes, 1 cup of water, Shredded cheddar cheese, Sour cream, Chopped green onions",
    "Instructions: Brown ground beef, drain excess fat, and add chili seasoning mix, chili beans, diced tomatoes, and water. Simmer until thickened. Serve chili topped with shredded cheddar cheese, sour cream, and chopped green onions."
  ],
  [
    "Ingredients: 2 cups of cooked and shredded chicken, 1/2 cup of buffalo sauce, 4 tortilla wraps, Shredded lettuce, Ranch dressing",
    "Instructions: Mix shredded chicken and buffalo sauce. Warm tortilla wraps and fill with buffalo chicken, shredded lettuce, and ranch dressing. Roll up for spicy buffalo chicken wraps."
  ],
  [
    "Ingredients: 2 cans of tuna in water, Drained and flaked, 1/2 cup of mayonnaise, 1/4 cup of diced celery, 1/4 cup of diced red onion, Salt and pepper to taste, Hamburger buns, Lettuce, Tomato slices",
    "Instructions: Mix flaked tuna, mayonnaise, diced celery, diced red onion, salt, and pepper in a bowl. Serve tuna salad on hamburger buns with lettuce and tomato slices for tuna salad sandwiches."
  ],
  [
    "Ingredients: 1 pound of ground beef, 1 packet of taco seasoning, 1/2 cup of water, 4 tortilla wraps, Shredded lettuce, Diced tomatoes, Shredded cheddar cheese, Sour cream, Salsa",
    "Instructions: Brown ground beef, drain excess fat, and add taco seasoning with water. Warm tortilla wraps and fill with seasoned beef, lettuce, diced tomatoes, cheddar cheese, sour cream, and salsa for flavorful beef tacos."
  ],
  [
    "Ingredients: 1 package of instant ramen noodles, 2 cups of water, 1/2 cup of frozen mixed vegetables, 1 egg, Soy sauce (optional)",
    "Instructions: Cook instant ramen noodles in water according to package instructions. Add frozen mixed vegetables and cook until heated through. In a bowl, whisk an egg and slowly pour it into the hot broth while stirring. Cook for another minute. Serve with a splash of soy sauce for quick and easy ramen soup."
  ],
  [
    "Ingredients: 4 boneless, skinless chicken breasts, 1 cup of breadcrumbs, 1/2 cup of grated Parmesan cheese, 1 teaspoon of Italian seasoning, Salt and pepper to taste, Marinara sauce, Shredded mozzarella cheese, Cooked spaghetti",
    "Instructions: Coat chicken breasts with breadcrumbs, grated Parmesan cheese, Italian seasoning, salt, and pepper. Bake in the oven until cooked through. Top with marinara sauce and shredded mozzarella cheese. Serve over cooked spaghetti for chicken Parmesan."
  ],
  [
    "Ingredients: 1 package of frozen mini corn dogs, Ketchup, Mustard",
    "Instructions: Cook frozen mini corn dogs according to package instructions. Serve with ketchup and mustard for a classic corn dog snack."
  ],
   [
    "Ingredients: 4 large oranges, 1 lemon",
    "Instructions: Squeeze the juice from the oranges and lemon. Mix well and serve chilled for a refreshing citrus blend."
  ],
  [
    "Ingredients: 2 apples, 2 carrots, 1-inch piece of ginger",
    "Instructions: Wash and chop the apples, carrots, and ginger. Run them through a juicer for a delicious and nutritious apple-carrot-ginger juice."
  ],
  [
    "Ingredients: 2 cups of fresh watermelon chunks, 1/2 cup of coconut water, 1 lime (juiced)",
    "Instructions: Blend watermelon chunks, coconut water, and lime juice until smooth. Serve over ice for a hydrating watermelon cooler."
  ],
  [
    "Ingredients: 2 cups of pineapple chunks, 1/2 cup of coconut milk, 1/2 cup of orange juice",
    "Instructions: Blend pineapple chunks, coconut milk, and orange juice until creamy. Pour into glasses for a tropical pineapple smoothie."
  ],
  [
    "Ingredients: 1 cup of strawberries, 1/2 cup of plain yogurt, 1/2 cup of milk, 2 tablespoons of honey (optional)",
    "Instructions: Blend strawberries, plain yogurt, milk, and honey (if desired) until smooth. Enjoy a creamy strawberry yogurt smoothie."
  ],
  [
    "Ingredients: 1 cucumber, 1/2 lemon (juiced), 1 sprig of fresh mint, 2 cups of water",
    "Instructions: Slice the cucumber and place it in a pitcher with lemon juice, fresh mint, and water. Let it infuse in the fridge for a refreshing cucumber mint detox water."
  ],
  [
    "Ingredients: 2 cups of fresh spinach, 1 ripe banana, 1/2 cup of pineapple chunks, 1/2 cup of coconut water",
    "Instructions: Blend fresh spinach, ripe banana, pineapple chunks, and coconut water until smooth. This green smoothie is packed with nutrients."
  ],
  [
    "Ingredients: 1 cup of frozen mixed berries (e.g., strawberries, blueberries, raspberries), 1/2 cup of Greek yogurt, 1/2 cup of almond milk, 1 tablespoon of honey (optional)",
    "Instructions: Blend frozen mixed berries, Greek yogurt, almond milk, and honey (if desired) until creamy. Serve as a berry yogurt smoothie."
  ],
  [
    "Ingredients: 2 cups of apple juice, 1/2 cup of cranberry juice, 1/2 cup of orange juice, 1/2 cup of pineapple juice, Ice cubes",
    "Instructions: Mix apple juice, cranberry juice, orange juice, and pineapple juice in a pitcher. Serve over ice for a refreshing fruit punch."
  ],
  [
    "Ingredients: 2 cups of freshly brewed iced tea, 1/2 cup of lemonade, Lemon slices, Mint leaves, Ice cubes",
    "Instructions: Combine freshly brewed iced tea and lemonade in a glass. Garnish with lemon slices, mint leaves, and ice cubes for a sweet and tangy Arnold Palmer."
  ],
  [
    "Ingredients: 3 ripe bananas, 1 cup of milk, 1/2 cup of orange juice, 1/2 cup of plain yogurt, 2 tablespoons of honey (optional), Ice cubes",
    "Instructions: Blend ripe bananas, milk, orange juice, plain yogurt, and honey (if desired) until smooth. Add ice cubes and blend again for a creamy banana-orange smoothie."
  ],
  [
    "Ingredients: 2 cups of fresh strawberries, 1 cup of pineapple chunks, 1/2 cup of coconut water, 1 tablespoon of lime juice, Ice cubes",
    "Instructions: Blend fresh strawberries, pineapple chunks, coconut water, and lime juice until smooth. Serve with ice cubes for a tropical strawberry-pineapple cooler."
  ],
  [
    "Ingredients: 1 cup of blueberries, 1/2 cup of plain yogurt, 1/2 cup of almond milk, 2 tablespoons of maple syrup, 1/2 teaspoon of vanilla extract",
    "Instructions: Blend blueberries, plain yogurt, almond milk, maple syrup, and vanilla extract until creamy. This blueberry yogurt smoothie is a sweet treat."
  ],
  [
    "Ingredients: 2 cups of watermelon chunks, 1/2 cup of fresh mint leaves, 1 lime (juiced), 1 teaspoon of agave nectar (optional), Ice cubes",
    "Instructions: Blend watermelon chunks, fresh mint leaves, lime juice, and agave nectar (if desired) until smooth. Serve with ice cubes for a refreshing watermelon mint cooler."
  ],
  [
    "Ingredients: 2 cups of cucumber slices, 1/2 cup of lemon juice, 1/4 cup of honey, 4 cups of water, Ice cubes",
    "Instructions: Blend cucumber slices, lemon juice, honey, and water until smooth. Chill in the fridge and serve over ice for a cool and hydrating cucumber lemonade."
  ],
  [
    "Ingredients: 1 cup of frozen mango chunks, 1/2 cup of plain yogurt, 1/2 cup of coconut milk, 2 tablespoons of honey (optional), Ice cubes",
    "Instructions: Blend frozen mango chunks, plain yogurt, coconut milk, and honey (if desired) until creamy. Enjoy a tropical mango yogurt smoothie."
  ],
  [
    "Ingredients: 2 cups of freshly squeezed orange juice, 1/2 cup of pomegranate juice, 1/2 cup of sparkling water, Orange slices, Pomegranate seeds, Ice cubes",
    "Instructions: Mix freshly squeezed orange juice, pomegranate juice, and sparkling water in a pitcher. Garnish with orange slices, pomegranate seeds, and ice cubes for a sparkling citrus punch."
  ],
  [
    "Ingredients: 2 cups of pineapple juice, 1/2 cup of coconut milk, 1/2 cup of mango juice, 1/2 cup of guava juice, Ice cubes",
    "Instructions: Mix pineapple juice, coconut milk, mango juice, and guava juice in a pitcher. Serve over ice for a tropical fruit medley."
  ],
  [
    "Ingredients: 1 cup of fresh raspberries, 1/2 cup of plain yogurt, 1/2 cup of almond milk, 2 tablespoons of honey (optional), Ice cubes",
    "Instructions: Blend fresh raspberries, plain yogurt, almond milk, and honey (if desired) until smooth. Enjoy a refreshing raspberry yogurt smoothie."
  ],
  [
    "Ingredients: 1 cup of fresh blueberries, 1/2 cup of orange juice, 1/2 cup of Greek yogurt, 2 tablespoons of honey (optional), Ice cubes",
    "Instructions: Blend fresh blueberries, orange juice, Greek yogurt, and honey (if desired) until creamy. Serve with ice cubes for a delightful blueberry-orange smoothie."
  ],
  [
    "Ingredients: 4 cups of mixed greens (e.g., lettuce, spinach, arugula), 1 cup of cherry tomatoes, 1/2 cup of cucumber slices, 1/4 cup of red onion (thinly sliced), Balsamic vinaigrette dressing",
    "Instructions: Toss mixed greens, cherry tomatoes, cucumber slices, and thinly sliced red onion in a bowl. Drizzle with balsamic vinaigrette dressing for a classic garden salad."
  ],
  [
    "Ingredients: 2 cups of cooked quinoa, 1 cup of chickpeas, 1 cup of diced cucumber, 1/2 cup of diced red bell pepper, 1/4 cup of fresh parsley (chopped), Lemon-tahini dressing",
    "Instructions: Combine cooked quinoa, chickpeas, diced cucumber, diced red bell pepper, and chopped fresh parsley in a bowl. Drizzle with lemon-tahini dressing for a quinoa chickpea salad."
  ],
  [
    "Ingredients: 4 hard-boiled eggs (sliced), 4 cups of mixed greens, 1 cup of cherry tomatoes, 1/2 cup of sliced cucumber, 1/4 cup of red onion (thinly sliced), Caesar dressing",
    "Instructions: Arrange sliced hard-boiled eggs, mixed greens, cherry tomatoes, sliced cucumber, and thinly sliced red onion on plates. Drizzle with Caesar dressing for a classic egg salad."
  ],
  [
    "Ingredients: 2 cups of cooked and shredded chicken breast, 1 cup of grapes (halved), 1/2 cup of celery (diced), 1/4 cup of chopped walnuts, Greek yogurt dressing",
    "Instructions: Mix shredded chicken breast, halved grapes, diced celery, and chopped walnuts in a bowl. Toss with Greek yogurt dressing for a chicken and grape salad."
  ],
  [
    "Ingredients: 2 cups of cooked pasta (e.g., rotini), 1 cup of cherry tomatoes (halved), 1/2 cup of mozzarella cheese (cubed), 1/4 cup of fresh basil leaves (chopped), Balsamic vinaigrette dressing",
    "Instructions: Combine cooked pasta, halved cherry tomatoes, cubed mozzarella cheese, and chopped fresh basil leaves in a bowl. Drizzle with balsamic vinaigrette dressing for a caprese pasta salad."
  ],
  [
    "Ingredients: 4 cups of baby spinach, 1 cup of sliced strawberries, 1/2 cup of crumbled feta cheese, 1/4 cup of candied pecans, Poppy seed dressing",
    "Instructions: Toss baby spinach, sliced strawberries, crumbled feta cheese, and candied pecans in a bowl. Drizzle with poppy seed dressing for a strawberry spinach salad."
  ],
  [
    "Ingredients: 2 cups of cooked and diced sweet potatoes, 1 cup of black beans (drained and rinsed), 1/2 cup of diced red bell pepper, 1/4 cup of chopped fresh cilantro, Lime-cumin dressing",
    "Instructions: Mix cooked diced sweet potatoes, black beans, diced red bell pepper, and chopped fresh cilantro in a bowl. Toss with lime-cumin dressing for a sweet potato and black bean salad."
  ],
  [
    "Ingredients: 4 cups of shredded kale, 1 cup of roasted chickpeas, 1/2 cup of grated Parmesan cheese, 1/4 cup of dried cranberries, Lemon-tahini dressing",
    "Instructions: Combine shredded kale, roasted chickpeas, grated Parmesan cheese, and dried cranberries in a bowl. Drizzle with lemon-tahini dressing for a kale and chickpea salad."
  ],
  [
    "Ingredients: 2 cups of cooked and diced chicken, 1 cup of red grapes (halved), 1/2 cup of celery (diced), 1/4 cup of chopped pecans, Greek yogurt dressing",
    "Instructions: Mix cooked diced chicken, halved red grapes, diced celery, and chopped pecans in a bowl. Toss with Greek yogurt dressing for a chicken and grape salad."
  ],
  [
    "Ingredients: 2 cups of cooked and cooled quinoa, 1 cup of diced cucumber, 1/2 cup of diced red onion, 1/4 cup of chopped fresh mint leaves, Lemon-tahini dressing",
    "Instructions: Combine cooked quinoa, diced cucumber, diced red onion, and chopped fresh mint leaves in a bowl. Drizzle with lemon-tahini dressing for a refreshing quinoa salad."
  ],
  [
    "Ingredients: 4 cups of mixed greens, 1 cup of cherry tomatoes (halved), 1/2 cup of sliced cucumber, 1/4 cup of crumbled feta cheese, Greek dressing",
    "Instructions: Toss mixed greens, halved cherry tomatoes, sliced cucumber, and crumbled feta cheese in a bowl. Drizzle with Greek dressing for a classic Greek salad."
  ],
  [
    "Ingredients: 2 cups of cooked and diced chicken breast, 1 cup of diced apple, 1/2 cup of diced celery, 1/4 cup of chopped pecans, Mayonnaise dressing",
    "Instructions: Mix diced chicken breast, diced apple, diced celery, and chopped pecans in a bowl. Toss with mayonnaise dressing for a chicken and apple salad."
  ],
  [
    "Ingredients: 2 cups of cooked farro, 1 cup of cherry tomatoes (halved), 1/2 cup of diced cucumber, 1/4 cup of chopped fresh basil leaves, Balsamic vinaigrette dressing",
    "Instructions: Combine cooked farro, halved cherry tomatoes, diced cucumber, and chopped fresh basil leaves in a bowl. Drizzle with balsamic vinaigrette dressing for a refreshing farro salad."
  ],
  [
    "Ingredients: 4 cups of mixed greens, 1 cup of sliced strawberries, 1/2 cup of crumbled goat cheese, 1/4 cup of candied pecans, Balsamic vinaigrette dressing",
    "Instructions: Toss mixed greens, sliced strawberries, crumbled goat cheese, and candied pecans in a bowl. Drizzle with balsamic vinaigrette dressing for a strawberry goat cheese salad."
  ],
  [
    "Ingredients: 2 cups of cooked and diced chicken, 1 cup of diced mango, 1/2 cup of diced red bell pepper, 1/4 cup of chopped fresh cilantro, Mango-lime dressing",
    "Instructions: Mix diced chicken, diced mango, diced red bell pepper, and chopped fresh cilantro in a bowl. Toss with mango-lime dressing for a chicken and mango salad."
  ],
  [
    "Ingredients: 2 cups of cooked quinoa, 1 cup of black beans (drained and rinsed), 1/2 cup of diced red onion, 1/4 cup of chopped fresh cilantro, Lime-cumin dressing",
    "Instructions: Combine cooked quinoa, black beans, diced red onion, and chopped fresh cilantro in a bowl. Drizzle with lime-cumin dressing for a quinoa black bean salad."
  ],
  [
    "Ingredients: 4 cups of baby spinach, 1 cup of sliced strawberries, 1/2 cup of sliced almonds, 1/4 cup of feta cheese crumbles, Poppy seed dressing",
    "Instructions: Toss baby spinach, sliced strawberries, sliced almonds, and feta cheese crumbles in a bowl. Drizzle with poppy seed dressing for a strawberry spinach salad."
  ],
  [
    "Ingredients: 2 cups of cooked and diced sweet potatoes, 1 cup of black beans (drained and rinsed), 1/2 cup of diced red onion, 1/4 cup of chopped fresh cilantro, Avocado-lime dressing",
    "Instructions: Mix cooked diced sweet potatoes, black beans, diced red onion, and chopped fresh cilantro in a bowl. Toss with avocado-lime dressing for a sweet potato and black bean salad."
  ],
  [
    "Ingredients: 4 cups of shredded kale, 1 cup of diced apple, 1/2 cup of crumbled feta cheese, 1/4 cup of chopped pecans, Balsamic vinaigrette dressing",
    "Instructions: Combine shredded kale, diced apple, crumbled feta cheese, and chopped pecans in a bowl. Drizzle with balsamic vinaigrette dressing for an apple kale salad."
  ]
]

# %%
testing_data = [
    [
        "Ingredients: 1 cup of rice, 2 cups of water, 1 tablespoon of butter, Salt to taste",
        "Instructions: Rinse the rice under cold water until the water runs clear. In a saucepan, bring water, rice, butter, and salt to a boil. Reduce heat, cover, and simmer for 18-20 minutes until the rice is tender and the water is absorbed. Fluff with a fork before serving."
    ],
    [
        "Ingredients: 2 boneless, skinless chicken breasts, 2 tablespoons of olive oil, 2 cloves of garlic (minced), 1 teaspoon of dried oregano, 1 teaspoon of dried basil, Salt and pepper to taste, 1 can of diced tomatoes, 1/4 cup of chicken broth, 1/4 cup of grated Parmesan cheese",
        "Instructions: Season chicken breasts with oregano, basil, salt, and pepper. In a skillet, heat olive oil over medium-high heat. Add chicken and cook until browned on both sides. Add garlic, diced tomatoes, and chicken broth. Simmer until chicken is cooked through. Sprinkle with Parmesan cheese before serving."
    ],
    [
        "Ingredients: 1 cup of quinoa, 2 cups of vegetable broth, 1 tablespoon of olive oil, 1 onion (chopped), 2 cloves of garlic (minced), 1 red bell pepper (chopped), 1 zucchini (chopped), 1 cup of corn kernels, 1 teaspoon of ground cumin, Salt and pepper to taste",
        "Instructions: Rinse quinoa under cold water. In a saucepan, heat olive oil over medium heat. Add onion, garlic, red bell pepper, and zucchini. Cook until vegetables are tender. Stir in quinoa, vegetable broth, corn kernels, cumin, salt, and pepper. Bring to a boil, then reduce heat and simmer covered for 15-20 minutes until quinoa is cooked and liquid is absorbed."
    ],
     [
        "Ingredients: 1 lb of salmon fillets, 2 tablespoons of lemon juice, 2 tablespoons of soy sauce, 2 cloves of garlic (minced), 1 tablespoon of honey, Salt and pepper to taste, Lemon wedges for garnish, Chopped parsley for garnish",
        "Instructions: Preheat oven to 375°F (190°C). In a small bowl, mix lemon juice, soy sauce, garlic, honey, salt, and pepper. Place salmon fillets on a baking dish and pour the sauce over them. Bake for 12-15 minutes until salmon is cooked through. Garnish with lemon wedges and chopped parsley before serving."
    ],
    [
        "Ingredients: 1 cup of quinoa, 2 cups of water, 1 tablespoon of olive oil, 1 onion (chopped), 2 cloves of garlic (minced), 1 red bell pepper (chopped), 1 yellow bell pepper (chopped), 1 can of black beans (drained and rinsed), 1 teaspoon of chili powder, Salt and pepper to taste, Lime wedges for garnish, Chopped cilantro for garnish",
        "Instructions: Rinse quinoa under cold water. In a saucepan, heat olive oil over medium heat. Add onion, garlic, and bell peppers. Cook until vegetables are tender. Stir in quinoa, water, black beans, chili powder, salt, and pepper. Bring to a boil, then reduce heat and simmer covered for 15-20 minutes until quinoa is cooked and liquid is absorbed. Garnish with lime wedges and chopped cilantro before serving."
    ],
    [
        "Ingredients: 2 cups of all-purpose flour, 1 tablespoon of baking powder, 1/2 teaspoon of salt, 1/4 cup of granulated sugar, 1 egg, 1 1/2 cups of milk, 1/4 cup of unsalted butter (melted), 1 teaspoon of vanilla extract, Butter or oil for cooking, Maple syrup for serving, Fresh berries for serving",
        "Instructions: In a bowl, whisk together flour, baking powder, salt, and sugar. In another bowl, beat egg and then stir in milk, melted butter, and vanilla extract. Add wet ingredients to dry ingredients and mix until just combined. Heat a skillet over medium heat and lightly grease with butter or oil. Pour 1/4 cup of batter onto the skillet for each pancake. Cook until bubbles form on the surface, then flip and cook until golden brown. Serve with maple syrup and fresh berries."
    ],
    [
        "Ingredients: 1 lb of beef tenderloin, 2 tablespoons of olive oil, 2 cloves of garlic (minced), 1 tablespoon of chopped fresh rosemary, Salt and pepper to taste, 1/4 cup of balsamic vinegar, 2 tablespoons of honey, 1/4 cup of beef broth",
        "Instructions: Preheat oven to 400°F (200°C). Rub beef tenderloin with olive oil, minced garlic, chopped rosemary, salt, and pepper. Heat an oven-safe skillet over high heat and sear the beef on all sides until browned. Transfer skillet to the oven and roast for about 15-20 minutes for medium-rare, or until desired doneness. Remove beef from skillet and let rest. In the same skillet, add balsamic vinegar, honey, and beef broth. Cook over medium heat until sauce thickens. Slice beef and serve with the balsamic glaze."
    ]
]

# %%
# !pip install datasets

# %%
# !pip install -q accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.4.7

import os
import torch
from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    HfArgumentParser,
    TrainingArguments,
    pipeline,
    logging,
)
from peft import LoraConfig, PeftModel
from trl import SFTTrainer
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kaggle-environments 1.14.3 requires transformers>=4.33.1, but you have transformers 4.31.0 which is incompatible.
# 2024-03-03 03:45:31.081651: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-03 03:45:31.081780: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-03 03:45:31.354006: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
torch.cuda.memory_allocated()
# Out:
# 15384612864

# %%
model_name = "NousResearch/llama-2-7b-chat-hf" # use this if you have access to the official LLaMA 2 model "meta-llama/Llama-2-7b-chat-hf", though keep in mind you'll need to pass a Hugging Face key argument
new_model = "llama-2-7b-custom"
lora_r = 64
lora_alpha = 16
lora_dropout = 0.1
use_4bit = True
bnb_4bit_compute_dtype = "float16"
bnb_4bit_quant_type = "nf4"
use_nested_quant = False
output_dir = "./results"
num_train_epochs = 1
fp16 = False
bf16 = False
per_device_train_batch_size = 4
per_device_eval_batch_size = 4
gradient_accumulation_steps = 1
gradient_checkpointing = True
max_grad_norm = 0.3
learning_rate = 2e-4
weight_decay = 0.001
optim = "paged_adamw_32bit"
lr_scheduler_type = "constant"
max_steps = -1
warmup_ratio = 0.03
group_by_length = True
save_steps = 25
logging_steps = 5
max_seq_length = None
packing = False
device_map = {"": 0}

# %% [markdown]
# for training data

# %%
from datasets import Dataset
# Converting train datas to the required format
formatted_data = {"ingredients": [], "instructions": []}
for data in training_data:
    formatted_data["ingredients"].append(data[0])
    formatted_data["instructions"].append(data[1])

# Creating a Hugging Face dataset
train_data = Dataset.from_dict(formatted_data)

# %%
train_data
# Out:
# Dataset({
#     features: ['ingredients', 'instructions'],
#     num_rows: 94
# })

# %% [markdown]
# for Test data

# %%
# Converting test datas to the required format
formatted_data = {"ingredients": [], "instructions": []}
for data in testing_data:
    formatted_data["ingredients"].append(data[0])
    formatted_data["instructions"].append(data[1])

# Creating a Hugging Face dataset
test_data = Dataset.from_dict(formatted_data)

# %%
system_message='Given the names and amount of the ingredients, make the instructions for preparing that food recipe delicious'

train_dataset_mapped=train_data.map(lambda examples: {'text': [f'[INST] <<SYS>>\n{system_message.strip()}\n<</SYS>>\n\n' + ingredients + ' [/INST] ' + instructions for ingredients, instructions in zip(examples['ingredients'], examples['instructions'])]}, batched=True)

valid_dataset_mapped=test_data.map(lambda examples: {'text': [f'[INST] <<SYS>>\n{system_message.strip()}\n<</SYS>>\n\n' + ingredients + ' [/INST] ' + instructions for ingredients, instructions in zip(examples['ingredients'], examples['instructions'])]}, batched=True)
# Out:
# ...
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
compute_dtype = getattr(torch, bnb_4bit_compute_dtype)
bnb_config = BitsAndBytesConfig(
    load_in_4bit=use_4bit,
    bnb_4bit_quant_type=bnb_4bit_quant_type,
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=use_nested_quant,
)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map=device_map
)
model.config.use_cache = False
model.config.pretraining_tp = 1
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    r=lora_r,
    bias="none",
    task_type="CAUSAL_LM",
)
# Set training parameters
training_arguments = TrainingArguments(
    output_dir=output_dir,
    num_train_epochs=num_train_epochs,
    per_device_train_batch_size=per_device_train_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,
    optim=optim,
    save_steps=save_steps,
    logging_steps=logging_steps,
    learning_rate=learning_rate,
    weight_decay=weight_decay,
    fp16=fp16,
    bf16=bf16,
    max_grad_norm=max_grad_norm,
    max_steps=max_steps,
    warmup_ratio=warmup_ratio,
    group_by_length=group_by_length,
    lr_scheduler_type=lr_scheduler_type,
    report_to="all",
    evaluation_strategy="steps",
    eval_steps=5  # Evaluate every 20 steps
)
# Set supervised fine-tuning parameters
trainer = SFTTrainer(
    model=model,
    train_dataset=train_dataset_mapped,
    eval_dataset=valid_dataset_mapped,  # Pass validation dataset here
    peft_config=peft_config,
    dataset_text_field="text",
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    args=training_arguments,
    packing=packing,
)
trainer.train()
trainer.model.save_pretrained(new_model)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/peft/utils/other.py:102: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/trl/trainer/sft_trainer.py:159: UserWarning: You didn't pass a `max_seq_length` argument to the SFTTrainer, this will default to 1024
#   warnings.warn(
# ...
#   0%|          | 0/1 [00:00<?, ?ba/s]
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='12' max='12' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [12/12 01:12, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
# ...

# %%
# Cell 4: Test the model
logging.set_verbosity(logging.CRITICAL)
prompt = f"[INST] <<SYS>>\n{system_message}\n<</SYS>>\n\n10 gram garlic powder, 10 ml honey [/INST]" # replace the command here with something relevant to your task
pipe = pipeline(task="text-generation", model=model, tokenizer=tokenizer, max_length=200)
result = pipe(prompt)
print(result[0]['generated_text'])
# Out:
# [INST] <<SYS>>
# Given the names and amount of the ingredients, make the instructions for preparing that food recipe delicious
# <</SYS>>
#
# 10 gram garlic powder, 10 ml honey [/INST]  Sure, here are the instructions for preparing the delicious food recipe:
#
# Ingredients:
#
# * 10 grams of garlic powder
# * 10 ml of honey
#
# Instructions:
#
# 1. Preheat your oven to 350 degrees Fahrenheit (180 degrees Celsius).
# 2. Mix the garlic powder and honey in a small bowl until well combined.
# 3. Place the mixture on a baking sheet lined with parchment paper.
# 4. Spread the mixture evenly across the baking sheet.
# 5. Bake

# %%
import os
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

# Define the directory where you want to save the model and tokenizer
model_path = "/kaggle/working/llama-2-7b-custom"

# Reload model in FP16 and merge it with LoRA weights
base_model = AutoModelForCausalLM.from_pretrained(
    model_name,
    low_cpu_mem_usage=True,
    return_dict=True,
    torch_dtype=torch.float16,
)  
model = PeftModel.from_pretrained(base_model, new_model)
model = model.merge_and_unload()

# Reload tokenizer to save it
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

# Create the directory if it doesn't exist
os.makedirs(model_path, exist_ok=True)

# Save the merged model and tokenizer to Kaggle's file system
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ('/kaggle/working/llama-2-7b-custom/tokenizer_config.json',
#  '/kaggle/working/llama-2-7b-custom/special_tokens_map.json',
#  '/kaggle/working/llama-2-7b-custom/tokenizer.model',
#  '/kaggle/working/llama-2-7b-custom/added_tokens.json',
#  '/kaggle/working/llama-2-7b-custom/tokenizer.json')

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
model.push_to_hub("dilip025/llama-2-7b")
tokenizer.push_to_hub("dilip025/llama-2-7b")
# Out:
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/dilip025/llama-2-7b/commit/85877a059825b7a95bdaefcf165e9fea83d78f23', commit_message='Upload tokenizer', commit_description='', oid='85877a059825b7a95bdaefcf165e9fea83d78f23', pr_url=None, pr_revision=None, pr_num=None)
